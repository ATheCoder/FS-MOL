# %%
import os
import pickle

base_path = '/FS-MOL/datasets/fs-mol-merged-cleaned/valid'

task_files = os.listdir(base_path)

tasks = [pickle.load(open(f'{base_path}/{path}', 'rb')) for path in task_files]

lengths = [len(task.samples) for task in tasks]


# Box plot lengths:
import matplotlib.pyplot as plt

plt.boxplot(lengths)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79dd9b623760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79dd9b7bde10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79dd9b622770>],
#  'medians': [<matplotlib.lines.Line2D at 0x79dd9b7bfb20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79dd9b7e1ae0>],
#  'means': []}

# %%
print(len(lengths))
# Out:
# 81

# %%
import math


81 * math.comb(260, 16) * math.comb(244, 16)
# Out:
# 4811134307547658282087310309449708842820610296818000
